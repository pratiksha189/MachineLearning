# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

from sklearn.impute import SimpleImputer 

import os
os.chdir("D:/Machine_Learning/Datasets") #fetch the dataset from the folder

# %%
ords=pd.read_csv("Orders.csv",parse_dates=['Order Date'],date_format='%d-%m-%Y')
ords.dtypes
# Out:
# Order ID             str
# Order Date           str
# Place of Shipment    str
# Mode of Payment      str
# dtype: object

# %%
ords['year']=ords['Order Date'].dt.year
ords['month']=ords['Order Date'].dt.month
ords['day']=ords['Order Date'].dt.day
ords['weekday']=ords['Order Date'].dt.weekday

# %%
ords
# Out:
#      Order ID Order Date Place of Shipment Mode of Payment
# 0   32 90 001  31-Dec-10              Pune          Cheque
# 1   32 90 002  06-Jan-11             Nasik          Online
# 2   32 90 003  14-Jan-11        Ahmednagar            Cash
# 3   32 90 004  18-Feb-11            Nanded          Cheque
# 4   32 90 005  19-Feb-11          Kolhapur            Cash
# ..        ...        ...               ...             ...
# 65  32 90 066  13-Jul-13          Nadurbar          Cheque
# 66  32 90 067  23-Jul-13             Dhule          Cheque
# 67  32 90 068  02-Aug-13         Ratnagiri          Online
# 68  32 90 069  04-Sep-13             Dhule          Cheque
# 69  32 90 070  07-Sep-13         Ratnagiri          Cheque
#
# [70 rows x 4 columns]

# %%
# remaining code

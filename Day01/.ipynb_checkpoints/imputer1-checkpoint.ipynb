# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import  train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,root_mean_squared_error
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer

# %%
os.chdir("C:/Users/PGCP-AI/Downloads/Cases/Chemical Process Data")

# %%
chem=pd.read_csv("ChemicalProcess.csv")
chem
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
chem.shape
# Out:
# (176, 58)

# %%
chem.isnull()
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    False                 False                 False                 False
# 1    False                 False                 False                 False
# 2    False                 False                 False                 False
# 3    False                 False                 False                 False
# 4    False                 False                 False                 False
# ..     ...                   ...                   ...                   ...
# 171  False                 False                 False                 False
# 172  False                 False                 False                 False
# 173  False                 False                 False                 False
# 174  False                 False                 False                 False
# 175  False                 False                 False                 False
#
# ...

# %%
chem["Yield"].isnull().sum()
# Out:
# np.int64(0)

# %%
chem.isnull().sum().sum()
# Out:
# np.int64(106)

# %%
os.chdir("C:/Users/PGCP-AI/Downloads/Datasets/Datasets")
job = pd.read_csv('JobSalary2.csv')
job
# Out:
#    S_No  Computer  Marketing  Engineer
# 0     1      84.0       55.0        75
# 1     2      90.0       53.0        70
# 2     3      63.0        NaN        88
# 3     4       NaN       50.0        77
# 4     5      63.0       41.0        89
# 5     6      75.0       54.0        85
# 6     7       NaN       51.0        96
# 7     8      77.0       64.0       105

# %%
const_imp = SimpleImputer(strategy = 'constant',fill_value=60).set_output(transform="pandas")
const_imp.fit_transform(job)
# Out:
#    S_No  Computer  Marketing  Engineer
# 0   1.0      84.0       55.0      75.0
# 1   2.0      90.0       53.0      70.0
# 2   3.0      63.0       60.0      88.0
# 3   4.0      60.0       50.0      77.0
# 4   5.0      63.0       41.0      89.0
# 5   6.0      75.0       54.0      85.0
# 6   7.0      60.0       51.0      96.0
# 7   8.0      77.0       64.0     105.0

# %%
mean_imp = SimpleImputer(strategy = 'mean',fill_value=60).set_output(transform="pandas")
mean_imp.fit(job)
# Out:
# SimpleImputer(fill_value=60)

# %%
mean_imp.fit_transform(job)
# Out:
#    S_No   Computer  Marketing  Engineer
# 0   1.0  84.000000  55.000000      75.0
# 1   2.0  90.000000  53.000000      70.0
# 2   3.0  63.000000  52.571429      88.0
# 3   4.0  75.333333  50.000000      77.0
# 4   5.0  63.000000  41.000000      89.0
# 5   6.0  75.000000  54.000000      85.0
# 6   7.0  75.333333  51.000000      96.0
# 7   8.0  77.000000  64.000000     105.0

# %%
median_imp = SimpleImputer(strategy = 'median',fill_value=60).set_output(transform="pandas")
median_imp.fit(job)
# Out:
# SimpleImputer(fill_value=60, strategy='median')

# %%
median_imp.fit_transform(job)
# Out:
#    S_No  Computer  Marketing  Engineer
# 0   1.0      84.0       55.0      75.0
# 1   2.0      90.0       53.0      70.0
# 2   3.0      63.0       53.0      88.0
# 3   4.0      76.0       50.0      77.0
# 4   5.0      63.0       41.0      89.0
# 5   6.0      75.0       54.0      85.0
# 6   7.0      76.0       51.0      96.0
# 7   8.0      77.0       64.0     105.0

# %%
os.chdir("C:/Users/PGCP-AI/Downloads/Machine-Learning-master/Machine-Learning-master")

# %%
housing = pd.read_csv('Housing.csv')
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
X=chem.drop("Yield",axis=1)
y=chem['Yield']

# %%
median_imp = SimpleImputer(strategy = 'median',fill_value=60).set_output(transform="pandas")

X_trn_imp=median_imp.fit_transform(X_train)

# X_tst_imp=mean_imp.fit_transform(X_test)
X_tst_imp = median_imp.transform(X_test)

lr = LinearRegression()

# lr.fit(X_train,y_train)
lr.fit(X_trn_imp, y_train)

y_pred=lr.predict(X_tst_imp)
print("R2=",r2_score(y_test,y_pred))
# Out:
# R2= -4.10570782574536

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=26) 
mean_imp = SimpleImputer(strategy = 'mean',fill_value=60).set_output(transform="pandas")
X_trn_imp=med_imp.fit_transform(X_train)

# X_tst_imp=mean_imp.fit_transform(X_test)
X_tst_imp = med_imp.transform(X_test)

lr = LinearRegression()

# lr.fit(X_train,y_train)
lr.fit(X_trn_imp, y_train)

y_pred=lr.predict(X_tst_imp)
print("R2=",r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=26)
#       2 mean_imp = SimpleImputer(strategy = 'mean',fill_value=60).set_output(transform="pandas")
# ----> 3 X_trn_imp=med_imp.fit_transform(X_train)
#       5 # X_tst_imp=mean_imp.fit_transform(X_test)
#       6 X_tst_imp = med_imp.transform(X_test)
#
# NameError: name 'med_imp' is not defined
